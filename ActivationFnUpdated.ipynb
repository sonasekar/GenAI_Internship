# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Activation Function: Sigmoid
# Formula: σ(x) = 1 / (1 + e^(-x))

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.linspace(-10, 10, 100)
y = sigmoid(x)

plt.plot(x, y)
plt.title("Sigmoid Activation Function")
plt.grid()
plt.show()

print("Example Input:", [-2, -1, 0, 1, 2])
print("Output:", sigmoid(np.array([-2, -1, 0, 1, 2])))
# Out:
# Example Input: [-2, -1, 0, 1, 2]
# Output: [0.11920292 0.26894142 0.5        0.73105858 0.88079708]

# %%
# Activation Function: Tanh
# Formula: tanh(x) = (e^x - e^(-x)) / (e^x + e^(-x))

def tanh(x):
    return np.tanh(x)

x = np.linspace(-10, 10, 100)
y = tanh(x)

plt.plot(x, y)
plt.title("Tanh Activation Function")
plt.grid()
plt.show()

print("Example Input:", [-2, -1, 0, 1, 2])
print("Output:", tanh(np.array([-2, -1, 0, 1, 2])))
# Out:
# Example Input: [-2, -1, 0, 1, 2]
# Output: [-0.96402758 -0.76159416  0.          0.76159416  0.96402758]

# %%
# Activation Function: ReLU
# Formula: ReLU(x) = max(0, x)

def relu(x):
    return np.maximum(0, x)

x = np.linspace(-10, 10, 100)
y = relu(x)

plt.plot(x, y)
plt.title("ReLU Activation Function")
plt.grid()
plt.show()

print("Example Input:", [-2, -1, 0, 1, 2])
print("Output:", relu(np.array([-2, -1, 0, 1, 2])))
# Out:
# Example Input: [-2, -1, 0, 1, 2]
# Output: [0 0 0 1 2]

# %%
# Activation Function: Leaky ReLU
# Formula: f(x) = x if x > 0 else 0.01 * x

def leaky_relu(x, alpha=0.01):
    return np.where(x > 0, x, alpha * x)

x = np.linspace(-10, 10, 100)
y = leaky_relu(x)

plt.plot(x, y)
plt.title("Leaky ReLU Activation Function")
plt.grid()
plt.show()

print("Example Input:", [-2, -1, 0, 1, 2])
print("Output:", leaky_relu(np.array([-2, -1, 0, 1, 2])))
# Out:
# Example Input: [-2, -1, 0, 1, 2]
# Output: [-0.02 -0.01  0.    1.    2.  ]

# %%
# Activation Function: Softmax
# Formula: softmax(x_i) = e^(x_i) / Σ e^(x_j)

def softmax(x):
    exp_x = np.exp(x - np.max(x))
    return exp_x / exp_x.sum()

x = np.array([2, 1, 0.1])
print("Input:", x)
print("Softmax Output:", softmax(x))
# Out:
# Input: [2.  1.  0.1]
# Softmax Output: [0.65900114 0.24243297 0.09856589]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Visualization of Sigmoid Activation Function
# Using new input range: -15 to 15

x = np.linspace(-15, 15, 300)
y = sigmoid(x)  # sigmoid function already defined in previous assignment

plt.figure(figsize=(6,4))
plt.plot(x, y)
plt.title("Sigmoid Activation Function Visualization")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()
plt.show()

# %%
# Visualization of Tanh Activation Function
# Using new input range: -8 to 8

x = np.linspace(-8, 8, 250)
y = tanh(x)  # tanh function already defined

plt.figure(figsize=(6,4))
plt.plot(x, y)
plt.title("Tanh Activation Function Visualization")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()
plt.show()

# %%
# Visualization of ReLU Activation Function
# Using new input range: -20 to 20

x = np.linspace(-20, 20, 300)
y = relu(x)  # relu function already defined

plt.figure(figsize=(6,4))
plt.plot(x, y)
plt.title("ReLU Activation Function Visualization")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()
plt.show()

# %%
# Visualization of Leaky ReLU Activation Function
# Using new input range: -10 to 10

x = np.linspace(-10, 10, 300)
y = leaky_relu(x)  # leaky_relu function already defined

plt.figure(figsize=(6,4))
plt.plot(x, y)
plt.title("Leaky ReLU Activation Function Visualization")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()
plt.show()

# %%
# Visualization of Softmax Activation Function
# Using new input vector values

x = np.array([3.0, 1.0, 0.1, 2.5, 4.0])
y = softmax(x)  # softmax function already defined

plt.figure(figsize=(6,4))
plt.bar(range(len(x)), y)
plt.title("Softmax Activation Function Visualization")
plt.xlabel("Index")
plt.ylabel("Probability Output")
plt.grid(axis='y')
plt.show()

print("Inputs:", x)
print("Softmax Outputs:", y)
# Out:
# Inputs: [3.  1.  0.1 2.5 4. ]
# Softmax Outputs: [0.22147555 0.02997346 0.0121863  0.13433171 0.60203298]
